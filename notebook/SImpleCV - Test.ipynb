# %%
## import Matpolt with PyQt4 Backend
import matplotlib
matplotlib.use('Qt4Agg')
import matplotlib.pyplot as plt

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from SimpleCV import *
init_options_handler.enable_notebook()

# %%
hiphoper = Image("test.jpg")
hiphoper.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x7fac1b256290)>

# %%
hiphoper_scaled =  hiphoper.adaptiveScale((128, 128))
hiphoper_scaled.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x7fac1aea1050)>

# %%
hiphoper_scaled.flipHorizontal().show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x7fac1b1cb488)>

# %%
img = Image('test.jpg')

corners = [(10, 0), (img.width, 0), (img.width, img.height), (10, img.height)]

straight = img.shear(corners)

straight.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x7fac1b1cb098)>

# %%
from SimpleCV import Image, Color

img = Image('test.jpg')

# Embiggen the image, put it on a green background, in the upper right
emb = img.embiggen((img.width+20, img.height), Color.BLACK, (00, 0))

emb.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x7fac1ae97638)>

# %%
def preprocessing(image, dest):
    save_128x128(image, dest + "_01.jpg")
    save_128x128(image.flipHorizontal(), dest + "_02.jpg")
    
    left20 = image.embiggen((image.width+20, image.height), Color.BLACK, (0, 0))
    save_128x128(left20, dest + "_03.jpg")
    save_128x128(left20.flipHorizontal(), dest + "_04.jpg")
    
    right20 = image.embiggen((image.width+20, image.height), Color.BLACK, (20, 0))
    save_128x128(right20, dest + "_05.jpg")
    save_128x128(right20.flipHorizontal(), dest + "_06.jpg")
    
def save_128x128(image, dest):
    image.adaptiveScale((128, 128)).save(dest)

# %%
img = Image('test.jpg')
dest = "000001"

preprocessing(img, dest)
